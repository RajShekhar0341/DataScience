# %% [markdown]
# <a href="https://colab.research.google.com/github/RajShekhar0341/DataScience/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
#Load DataSet
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("Training samples:", x_train.shape)
print("Testing samples:", x_test.shape)
# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training samples: (60000, 28, 28)
# Testing samples: (10000, 28, 28)

# %%
# Convert labels to one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
#Step 4: Build the Feedforward Neural Network
model = Sequential()

# %%
# Flatten input layer
model.add(Flatten(input_shape=(28,28)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Output layer (10 classes)
model.add(Dense(10, activation='softmax'))
#Step 5: Compile the Model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Step 6: Train the Model
model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8693 - loss: 0.5053 - val_accuracy: 0.9147 - val_loss: 0.3168
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9110 - loss: 0.3180 - val_accuracy: 0.9214 - val_loss: 0.2867
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9175 - loss: 0.2938 - val_accuracy: 0.9224 - val_loss: 0.2791
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9211 - loss: 0.2811 - val_accuracy: 0.9262 - val_loss: 0.2660
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9235 - loss: 0.2737 - val_accuracy: 0.9257 - val_loss: 0.2663
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9249 - loss: 0.2684 - val_accuracy: 0.9283 - val_loss: 0.2644
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9250 - loss: 0.2645 - val_accuracy: 0.9284 - val_loss: 0.2626
# Epoch 8/10
# ...

# %%
#Step 7: Evaluate the Model
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_accuracy)
#Step 8: Make Predictions
predictions = model.predict(x_test)

import numpy as np
print("Predicted digit:", np.argmax(predictions[0]))
print("Actual digit:", np.argmax(y_test[0]))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9273 - loss: 0.2646
# Test Accuracy: 0.927299976348877
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Predicted digit: 7
# Actual digit: 7
