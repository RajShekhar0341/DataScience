# %% [markdown]
# <a href="https://colab.research.google.com/github/RajShekhar0341/DataScience/blob/main/K_Means_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#start with data visualising some data points
import matplotlib.pyplot as plt
x=[4,5,10,4,3,11,14,6,10,12]
y=[21,19,24,17,16,25,24,22,21,21]
plt.scatter(x,y)
plt.show()

# %%
#what should be the ideal value of K? Elbow Method
from sklearn.cluster import KMeans

data=list(zip(x,y))
intertias= []

for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(data)
    intertias.append(kmeans.inertia_)

plt.plot(range(1,11),intertias,marker='o')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Intertia/Centroids')
plt.show()

# %%
#construction of the Model
kmeans=KMeans(n_clusters=2)
kmeans.fit(data)

plt.scatter(x,y,c=kmeans.labels_)
plt.show()
