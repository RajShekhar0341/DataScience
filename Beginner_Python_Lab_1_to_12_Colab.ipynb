# %% [markdown]
# <a href="https://colab.research.google.com/github/RajShekhar0341/DataScience/blob/main/Beginner_Python_Lab_1_to_12_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Beginner Python Lab (Items 1–12) — Colab Ready
#
# This notebook covers:
# 1. Variables, data types, input, type conversions (implicit & explicit)
# 2. Operators: arithmetic, relational, logical, bitwise, assignment
# 3. Decision making (if/elif/else)
# 4. Loops (Fibonacci, Sum 1..n, Factorial)
# 5. Nested loops: patterns (inverted pyramid, Floyd's triangle)
# 6. Loop controls: break, continue, pass
# 7. User-defined functions, scope/lifetime, return values (factorial)
# 8. Prime checker function
# 9. Lambda: square of a number
# 10. String manipulation: slicing, substring, comparison, immutability
# 11. Lists: indexing, slicing, modify, append/insert/remove + Nested list access
# 12. Stack using list: push/pop
#
# **How to use:** Run cells top-to-bottom. Cells with `input()` will prompt you in Colab.

# %% [markdown]
# ## 1) Variables, data types, input, and type conversion (implicit & explicit)

# %%
# Variables, data types, input, conversions
name = input("Enter your name: ")
age_str = input("Enter your age: ")
height_str = input("Enter your height in meters (e.g., 1.73): ")

# explicit conversions
try:
    age = int(age_str)
except ValueError:
    print("Invalid age; default 0.")
    age = 0

try:
    height = float(height_str)
except ValueError:
    print("Invalid height; default 0.0.")
    height = 0.0

# implicit conversion demo
x = 10      # int
y = 3.5     # float
z = x + y   # implicit int->float

is_adult = age >= 18

print("\n--- Summary ---")
print(f"Name: {name} (type={type(name).__name__})")
print(f"Age: {age} (type={type(age).__name__})")
print(f"Height: {height} (type={type(height).__name__})")
print(f"x + y = {z} (implicit -> {type(z).__name__})")
print(f"Adult? {is_adult} (type={type(is_adult).__name__})")

pi = 3.14159
pi_as_int = int(pi)  # explicit truncation
print(f"Explicit: float {pi} -> int {pi_as_int}")

# %% [markdown]
# ## 2) Operators: Arithmetic, Relational, Logical, Bitwise, Assignment

# %% [markdown]
# ### 2a) Accept two numbers and perform arithmetic operations

# %%
a = float(input("Enter number a: "))
b = float(input("Enter number b: "))

print("\n--- Arithmetic ---")
print(f"a + b = {a + b}")
print(f"a - b = {a - b}")
print(f"a * b = {a * b}")
try:
    print(f"a ** b = {a ** b}")
except OverflowError:
    print("a ** b overflowed.")
if b != 0:
    print(f"a / b  = {a / b}")
    print(f"a // b = {a // b}")
    print(f"a % b  = {a % b}")
else:
    print("Division, floor, and modulus undefined for b = 0")

# %% [markdown]
# ### 2b) Logical condition: check if a number is positive and even

# %%
n = int(input("Enter an integer: "))
is_positive = n > 0
is_even = (n % 2 == 0)
if is_positive and is_even:
    print(f"{n} is positive and even.")
else:
    print(f"{n} is NOT both positive and even.")

# %% [markdown]
# ### 2c) Bitwise operators: XOR swap without a temp variable

# %%
x = int(input("Enter x: "))
y = int(input("Enter y: "))
print(f"Before swap: x={x}, y={y}")
x ^= y
y ^= x
x ^= y
print(f"After  swap: x={x}, y={y}")

# %% [markdown]
# ### (Bonus) Relational, logical, bitwise, assignment overview

# %%
p, q = 5, 7
print("\n--- Relational ---")
print(p == q, p != q, p > q, p >= q, p < q, p <= q)

A, B = True, False
print("\n--- Logical ---")
print("A and B:", A and B)
print("A or  B:", A or B)
print("not A  :", not A)

m, n2 = 6, 3
print("\n--- Bitwise ---")
print("m & n :", m & n2)
print("m | n :", m | n2)
print("m ^ n :", m ^ n2)
print("~m    :", ~m)
print("m<<1  :", m << 1)
print("m>>1  :", m >> 1)

r = 10
print("\n--- Assignment ---")
r += 5; print("r += 5 ->", r)
r -= 3; print("r -= 3 ->", r)
r *= 2; print("r *= 2 ->", r)
r //= 4; print("r //= 4 ->", r)
r %= 3; print("r %= 3 ->", r)
r **= 2; print("r **= 2 ->", r)

# %% [markdown]
# ## 3) Decision-making statements

# %% [markdown]
# ### 3a) Check positive, negative, or zero

# %%
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

# %% [markdown]
# ### 3b) Grade calculator (if-elif-else)

# %%
marks = float(input("Enter marks (0-100): "))

if marks < 0 or marks > 100:
    print("Invalid marks.")
elif marks >= 90:
    grade = "A+"
elif marks >= 80:
    grade = "A"
elif marks >= 70:
    grade = "B"
elif marks >= 60:
    grade = "C"
elif marks >= 50:
    grade = "D"
else:
    grade = "F"

if 0 <= marks <= 100:
    print(f"Grade: {grade}")

# %% [markdown]
# ### 3c) Leap year checker

# %%
year = int(input("Enter a year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")

# %% [markdown]
# ## 4) Loops: for, while, range

# %% [markdown]
# ### 4a) First n Fibonacci numbers (while loop)

# %%
n = int(input("Enter n (>=1) for Fibonacci: "))
a, b = 0, 1
count = 0
fib_list = []
while count < n:
    fib_list.append(a)
    a, b = b, a + b
    count += 1
print("Fibonacci:", fib_list)

# %% [markdown]
# ### 4b) Sum of 1..n using for loop

# %%
n = int(input("Enter n (>=1) to sum 1..n: "))
total = 0
for i in range(1, n + 1):
    total += i
print("Sum =", total)

# %% [markdown]
# ### 4c) Factorial using while loop

# %%
n = int(input("Enter n (>=0) for factorial: "))
if n < 0:
    print("Factorial not defined for negative numbers.")
else:
    fact = 1
    i = 1
    while i <= n:
        fact *= i
        i += 1
    print(f"{n}! = {fact}")

# %% [markdown]
# ## 5) Nested loops: patterns

# %% [markdown]
# ### 5a) Inverted pyramid pattern

# %%
rows = int(input("Enter number of rows for inverted pyramid: "))
for i in range(rows):
    spaces = " " * i
    stars = "*" * (2 * (rows - i) - 1)
    print(spaces + stars)

# %% [markdown]
# ### 5b) Floyd’s Triangle

# %%
rows = int(input("Enter number of rows for Floyd's Triangle: "))
num = 1
for i in range(1, rows + 1):
    line = []
    for _ in range(i):
        line.append(str(num))
        num += 1
    print(" ".join(line))

# %% [markdown]
# ## 6) break, continue, pass

# %% [markdown]
# ### 6a) Print 1..10 skipping multiples of 3 (continue)

# %%
for i in range(1, 11):
    if i % 3 == 0:
        continue
    print(i, end=" ")
print()

# %% [markdown]
# ### 6b) Break when reaching 7

# %%
for i in range(1, 11):
    if i == 7:
        print("\nReached 7 -> breaking.")
        break
    print(i, end=" ")
print()

# %% [markdown]
# ### 6c) Use `pass` inside a loop (no-op)

# %%
for i in range(5):
    if i == 2:
        pass  # placeholder; does nothing
    print("i =", i)
print("Explanation: 'pass' does nothing; keeps block syntactically valid.")

# %% [markdown]
# ## 7) User-defined functions, scope/lifetime, and return values

# %%
def factorial(n: int) -> int:
    if n < 0:
        raise ValueError("Factorial is not defined for negative numbers.")
    result = 1
    for i in range(2, n + 1):
        result *= i
    return result

print("5! =", factorial(5))

# %%
counter = 0  # global variable

def increment_local(counter):
    counter += 1
    return counter

def increment_global():
    global counter
    counter += 1
    return counter

def outer():
    msg = "outer"
    def inner():
        nonlocal msg
        msg = "updated by inner"
        return msg
    inner()
    return msg

print("increment_local(10) ->", increment_local(10))
print("global before ->", counter)
print("increment_global() ->", increment_global())
print("global after  ->", counter)
print("outer()/nonlocal demo ->", outer())

# %% [markdown]
# ## 8) Prime checker function

# %%
def is_prime(n: int) -> bool:
    if n < 2:
        return False
    if n % 2 == 0:
        return n == 2
    i = 3
    while i * i <= n:
        if n % i == 0:
            return False
        i += 2
    return True

for x in [0, 1, 2, 3, 4, 17, 18, 19, 20]:
    print(f"{x} prime? -> {is_prime(x)}")

# %% [markdown]
# ## 9) Lambda: square of a number

# %%
square = lambda x: x * x
print("square(7) =", square(7))

# %%
cube = lambda y: y * y * y
print("cube(6) =", cube(6))
# Out:
# cube(6) = 216

# %% [markdown]
# ## 10) Strings: slicing, substring ops, comparisons, immutability

# %%
s = "Data Science"

print("len:", len(s))
print("s[0]       :", s[0])
print("s[-1]      :", s[-1])
print("s[0:4]     :", s[0:4])
print("s[5:]      :", s[5:])
print("s[:4]      :", s[:4])
print("s[::2]     :", s[::2])
print("s[::-1]    :", s[::-1])

print("'Sci' in s :", "Sci" in s)
print("s.find('a'):", s.find('a'))
print("s.count('e'):", s.count('e'))
print("s.upper()  :", s.upper())
print("s.lower()  :", s.lower())
print("s.replace('Data','AI'):", s.replace("Data", "AI"))
print("s.startswith('Data'):", s.startswith("Data"))
print("s.endswith('ence')  :", s.endswith("ence"))
print("s.split()  :", s.split())
print("' - '.join(['A','B','C']):", " - ".join(["A","B","C"]))

print("'Apple' < 'Banana' ->", "Apple" < "Banana")
print("'abc' == 'ABC'     ->", "abc" == "ABC")
print("'abc'.casefold()== 'ABC'.casefold() ->", "abc".casefold() == "ABC".casefold())

s2 = "X" + s[1:]
print("modified copy:", s2)

# %% [markdown]
# ## 11) Lists: indexing, slicing, modify, append/insert/remove + Nested lists

# %%
students = ["Raj", "Swathi", "Amala", "Gulshan", "Anudeep"]
print("First:", students[0])
print("Last :", students[-1])
print("Slice [1:4]:", students[1:4])

students[2] = "Amala R"
print("After modify:", students)

students.append("Kalpana")
print("After append:", students)

students.insert(2, "Vishal")
print("After insert:", students)

name = "Gulshan"
if name in students:
    students.remove(name)
    print(f"After remove({name!r}):", students)

popped = students.pop()
print("Popped:", popped)
print("Final list:", students)

records = [
    ["Raj",     [85, 90, 88]],
    ["Swathi",  [92, 81, 95]],
    ["Amala",   [78, 84, 80]],
]
print("Amala 2nd mark:", records[2][1][1])
records[0][1].append(93)
print("Raj marks after append:", records[0][1])
for name, marks in records:
    avg = sum(marks) / len(marks)
    print(f"{name}: marks={marks}, avg={avg:.2f}")

# %% [markdown]
# ## 12) Stack using list: push and pop

# %%
stack = []

def push(item):
    stack.append(item)
    print(f"Pushed {item}; stack -> {stack}")

def pop_():
    if not stack:
        print("Underflow: stack is empty.")
        return None
    item = stack.pop()
    print(f"Popped {item}; stack -> {stack}")
    return item

push(10)
push(20)
push(30)
pop_()
pop_()
pop_()
pop_()  # underflow

# %%
s = "Data science"
print("len:", len(s))
print("s[0]:", s[0])
print("s[0]       :", s[0])
# Out:
# len: 12
# s[0]: D
